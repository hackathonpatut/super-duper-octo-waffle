# %%
import pandas as pd
import numpy as np

# %%
import dask.dataframe as dd

data_path = '../data'
receipts = 'Junction_Data.csv'
receipts_sample = 'Junction_SampleData.csv'

# Dtypes https://docs.scipy.org/doc/numpy-1.15.0/user/basics.types.html
# %time ddf = dd.read_csv(data_path + '/' + receipts, sep=';', \
                       dtype={'Receipt': str, 'EAN': str,'KCustomer': 'int16'})
# Out:
# Wall time: 69 ms

# %%
KCustomer = df.loc[:,['EAN', 'KCustomer']]

# %%
# %time df2 = pd.read_csv(data_path + '/' + receipts_sample, sep=';' )
# %time ddfs = dd.read_csv(data_path + '/' + receipts_sample, sep=';',  \
                       dtype={'Receipt': str, 'EAN': str,'KCustomer': str})
ddfs = ddfs.categorize("KCustomer")
# Out:
# Wall time: 20 ms
# Wall time: 20 ms

# %%
help(dd.to_csv)
# Out:
# Help on function to_csv in module dask.dataframe.io.csv:
#
# to_csv(df, filename, name_function=None, compression=None, compute=True, scheduler=None, storage_options=None, header_first_partition_only=False, **kwargs)
#     Store Dask DataFrame to CSV files
#
#     One filename per partition will be created. You can specify the
#     filenames in a variety of ways.
#
#     Use a globstring::
#
#     >>> df.to_csv('/path/to/data/export-*.csv')  # doctest: +SKIP
#
#     The * will be replaced by the increasing sequence 0, 1, 2, ...
#
#     ::
#
#         /path/to/data/export-0.csv
#         /path/to/data/export-1.csv
#
#     Use a globstring and a ``name_function=`` keyword argument.  The
#     name_function function should expect an integer and produce a string.
#     Strings produced by name_function must preserve the order of their
#     respective partition indices.
#
#     >>> from datetime import date, timedelta
#     >>> def name(i):
# ...

# %%
ddf_slice = ddf.head(500000)

# %%
ddf_slice_filt = ddf_slice.EAN.unique

# %%
len(ddf_slice['EAN'].unique())
# Out:
# 29554

# %%
ddf_slice.columns
# Out:
# Index(['Receipt', 'TransactionDate', 'BeginHour', 'EAN', 'Quantity',
#        'PersonAgeGrp', 'KCustomer', 'QualClass', 'EasyClass'],
#       dtype='object')

# %%
shopping_baskets = ddf_slice[["Receipt", "EAN"]]
shopping_baskets.to_csv("../data/baskets_500k.csv", sep=";", index=False)

# %%
# Count how many items were in a single shoping basket
counts = shopping_baskets.groupby(by="Receipt").size()
basket_sizes = pd.DataFrame(counts)
basket_sizes.to_csv("../data/basket_sizes.csv", sep=";")

# %%
shopping_baskets[["Receipt"]].nunique()
# Out:
# Receipt    62663
# dtype: int64

# %%
eans = pd.DataFrame(ddf_slice['EAN'].unique())
eans.to_csv('data_50k.csv', sep=";", index=False)

# %%
eans_all = pd.DataFrame(ddf['EAN'].unique(), columns = ['EAN'])
eans_all.to_csv('eans_all.csv', sep=";", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\mattisi\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             try:
# --> 410                 arr = np.array(data, dtype=dtype, copy=copy)
#     411             except (ValueError, TypeError) as e:
#
# C:\Users\mattisi\Anaconda3\lib\site-packages\dask\dataframe\core.py in __array__(self, dtype, **kwargs)
#     310     def __array__(self, dtype=None, **kwargs):
# --> 311         self._computed = self.compute()
#     312         x = np.array(self._computed)
#
# C:\Users\mattisi\Anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#
# C:\Users\mattisi\Anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
# ...

# %%
ddf_slice.to_csv('data_50k.csv',)
# Out:
#      Receipt TransactionDate  BeginHour            EAN   Quantity  \
# 0   13735389      2017-01-01         21  4001724819608   1,000000
# 1   13735389      2017-01-01         21  6411402197108   1,000000
# 2   13735438      2017-01-01         13  6411402202208   1,000000
# 3   13735438      2017-01-01         13  6407810016636   1,000000
# 4   13735438      2017-01-01         13  6416046654123   1,000000
# 5   13735438      2017-01-01         13  2000619500005   0,844000
# 6   13735438      2017-01-01         13  6408430310869   1,000000
# 7   13735438      2017-01-01         13  2000797000007   0,996000
# 8   13735438      2017-01-01         13  5410146414497   1,000000
# 9   13735438      2017-01-01         13  8718114868943   1,000000
# 10  13735438      2017-01-01         13  6408430000548   1,000000
# 11  13735438      2017-01-01         13  6409290001492   1,000000
# 12  13735613      2017-01-01         15  7622100936077   1,000000
# ...

# %%
ddf_slice = ddf.reset_index()[0:10].compute()

# %%
# https://stackoverflow.com/questions/42636152/after-using-dask-pivot-table-i-lose-the-index-column
KCustomer = KCustomer.categorize("KCustomer")
customer_pivot = KCustomer.pivot_table(values='EAN', index='KCustomer', columns='KCustomer', aggfunc='count').compute()
customer_pivot
# Out:
# KCustomer     6713.0     6715.0     6711.0      6712.0     6714.0
# KCustomer
# 6713.0     7050872.0        0.0        0.0         0.0        0.0
# 6715.0           0.0  4111243.0        0.0         0.0        0.0
# 6711.0           0.0        0.0  9414712.0         0.0        0.0
# 6712.0           0.0        0.0        0.0  20675378.0        0.0
# 6714.0           0.0        0.0        0.0         0.0  3514830.0

# %%
n_receipts = KCustomer.shape[0].compute()
print("Datassa contains " + str(n_receipts) + " row")
# Out:
# Datassa contains 44767036 row

# %%
ean_pivot.shape
# Out:
# (107135, 0)

# %%
KCustomer2 = KCustomer.loc[1:200,:]

# %%
KCustomer2.shape[0].compute()
# Out:
# 11200

# %%
uniq

# %%
dfs.groupby('KCustomer')['KCustomer'].aggregate(len)
# Out:
# KCustomer
# 6711    2068
# 6712    2132
# 6713    2111
# 6714    1612
# 6715    2077
# Name: KCustomer, dtype: int64
